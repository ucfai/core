# %% [markdown]
# <img src="https://ucfai.org//ucfai/core/sp20/2020-02-26-meeting05/meeting05/banner.png">
#
# <div class="col-12">
#     <span class="btn btn-success btn-block">
#         Meeting in-person? Have you signed in?
#     </span>
# </div>
#
# <div class="col-12">
#     <h1> meeting05 </h1>
#     <hr>
# </div>
#
# <div style="line-height: 2em;">
#     <p>by:  on 2020-02-26</p>
# </div>
